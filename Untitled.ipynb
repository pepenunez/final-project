# %%
import pandas as pd

# %%
interactions = pd.read_csv('data/to_sql/interactions.csv')
recipes = pd.read_csv('data/to_sql/recipes.csv')

# %%
interactions.head()
# Out:
#    Unnamed: 0   user_id  recipe_id  rating
# 0           0   8542392     222388       5
# 1           1  11174581     222388       5
# 2           2   8262477     222388       5
# 3           3   3574785     240488       5
# 4           4  12145410     240488       2

# %%
recipes.head()
# Out:
#    Unnamed: 0  recipe_id                        recipe_name  aver_rate  \
# 0           0     222388                     Homemade Bacon   5.000000
# 1           1     240488  Pork Loin, Apples, and Sauerkraut   4.764706
# 2           2     218939   Foolproof Rosemary Chicken Wings   4.571429
# 3           3      87211              Chicken Pesto Paninis   4.625000
# 4           4     245714                 Potato Bacon Pizza   4.500000
#
#    review_nums                                        ingredients
# 0            3  ['pork belly', 'smoked paprika', 'kosher salt'...
# 1           29  ['sauerkraut drained', 'Granny Smith apples sl...
# 2           12  ['chicken wings', 'sprigs rosemary', 'head gar...
# 3          163  ['focaccia bread quartered', 'prepared basil p...
# 4            2  ['red potatoes', 'strips bacon', 'Sauce:', 'he...

# %%
interactions_recipes_temp = pd.merge(interactions, recipes, how='left', on='recipe_id')

# %%
interactions_recipes_temp.head(200)
# Out:
#      Unnamed: 0_x   user_id  recipe_id  rating  Unnamed: 0_y  \
# 0               0   8542392     222388       5             0
# 1               1  11174581     222388       5             0
# 2               2   8262477     222388       5             0
# 3               3   3574785     240488       5             1
# 4               4  12145410     240488       2             1
# ..            ...       ...        ...     ...           ...
# 195           195    743666      87211       5             3
# 196           196   2868211      87211       5             3
# 197           197   2549374      87211       4             3
# 198           198   9648389      87211       5             3
# 199           199   4610345      87211       5             3
#
#                            recipe_name  aver_rate  review_nums  \
# 0                       Homemade Bacon   5.000000            3
# 1                       Homemade Bacon   5.000000            3
# ...
